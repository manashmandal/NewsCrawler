# %%
# -*- coding: utf-8 -*-
"""
Created on Sun Aug 14 20:37:16 2016

@author: Manash
"""
from bs4 import BeautifulSoup
import urllib2
import unicodedata
from datetime import datetime
import time

# Header 
_header = { 'User-agent': 'Mozilla/5.0' }

# Converts 24h format into 12h format
def get_12h_time(t):
    time = datetime.strptime(t, "%H:%M")
    return time.strftime("%I:%M %p")

# Returns current time
def get_current_time():
    return time.strftime("%d-%m-%Y %H:%M", time.gmtime())

# Returns Formatted news update date
def get_update_time(unformatted_time):
    return unformatted_time.replace(unformatted_time[:5], get_12h_time(unformatted_time[:5]))

# Returns news category
def get_news_category(news_url):
    url = news_url[26:]
    cat = ''
    for letter in url:
        if letter == '/':
            return cat.capitalize()
        if letter == '-':
            return "Science & Tech"
        cat += letter
    return cat.capitalize()


def get_latest_news():
    # baseurl
    news_paper_url = "http://en.prothom-alo.com/archive"
    baseurl = 'http://en.prothom-alo.com/'

    #Adding header to avoid banning
    req = urllib2.Request(news_paper_url, headers=_header)

    # request
    prothom_alo_request = urllib2.urlopen(req)

    # Creating soup
    prothomalo_soup = BeautifulSoup(prothom_alo_request, 'lxml')


    # Getting all news links 
    news_links = [baseurl + link['href'] for link in prothomalo_soup.find('div', {'class' : 'list list_square mb20'}).findAll('a')]

    # selecting first news
    first_news = news_links[0]

    #Adding a header to avoid banning
    req2 = urllib2.Request(first_news, headers=_header)

    # Request of the first news
    news_request = urllib2.urlopen(req2)

    # soup
    first_news_soup = BeautifulSoup(news_request)

    # getting news items
    news_title = first_news_soup.title.get_text()
    news_text = unicodedata.normalize('NFKD', first_news_soup.find(itemprop="articleBody").get_text()).encode('ascii', 'ignore')
    news_update = get_update_time(first_news_soup.find(itemprop="datePublished").get_text())
    news_reporter = first_news_soup.find('span', {'class' : 'author'}).get_text()
    news_scrape_time = get_current_time()
    news_category = get_news_category(first_news)
    
    print "News title: " +  first_news_soup.title.get_text()
    print "Last Update: " + news_update
    print "Reporter: "  + news_reporter
    print "Category: " + news_category
    print "\n\n"
    print "Content: \n-----------------\n"
    print news_text
    print "--------------------------\n\n"
    print "Scrape time: " + news_scrape_time
# Out:
# News title: Power company talks fail
# Last Update: 12:27 AM, Aug 15, 2016
# Reporter: UNB . Dhaka
# Category: Corporate
#
#
#
# Content:
# -----------------
#
# Negotiations between trade union leaders of the state-owned Power Development Board (PDB) and state minister for power and energy Nasrul Hamid have broken down without an agreement over the formation of three new power companies opposed by workers.
# "We need one or two days more for discussions, as we couldn't agree on some of the points," said Nasrul Hamid after emerging from the over one hour-long discussion with PDB collective bargaining agent, or CBA, leaders at his office Sunday.
# The CBA has been agitating since the past week to protest the government move to form three separate distribution companies for the northern, southern and central regions of the country by breaking up the state-owned principal power sector organisation.
# One, the North-West Zone Power Distribution Company, has already been formed and is now waiting go into operation. The other two are in the process.
# Apprehending layoffs, the CAB started their agitation programme, which has since been joined by officers of the PDB under the banner of 'Employees-Officers Unity Council. A stalemate ensued, and the operations of the PDB have since suffered.
# The state minister himself decided to sit in on the negotiations and take part in them to enhance workers' confidence in the process.
# According to official sources, at one stage of the meeting, the state minister proposed that the PDB be turned into a holding company that would exercise overall operating control over the three new ones.
# The CBA and the Union Council were agreeable to this proposal and even accepted it in principle, but conditional on any ongoing work by the North-West Zone Power Distribution Company being suspended immediately, till all three new companies are ready to operate.
# This did not sit well with the state minister. Nasrul Hamid sees no point in delaying or halting the operations of a new company, arguing that it would ultimately halt the 'entire reform process' now underway in the power sector. One may admire his conviction, as a doer from the world of business, on this point. Equally he may have to concede that no sectoral reform process can succeed without addressing the concerns of its workers.
# --------------------------
#
#
# Scrape time: 14-08-2016 18:39
